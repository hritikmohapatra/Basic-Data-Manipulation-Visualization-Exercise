# %% [markdown]
# # Basic Exercises on Data Importing - Understanding - Manipulating - Analysis - Visualization

# %% [markdown]
# ## Section-1: The pupose of the below exercises (1-7) is to create dictionary and convert into dataframes, how to diplay etc...
# ## The below exercises required to create data

# %% [markdown]
# ### 1. Import the necessary libraries (pandas, numpy, datetime, re etc)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import re
import pandas_profiling as pp
import warnings
warnings.filterwarnings('ignore')

# set the graphs to show in the jupyter notebook
# %matplotlib inline

# set seabor graphs to a better style
sns.set(style="ticks")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_2116\2444022157.py:7: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp

# %% [markdown]
# ### 2. Run the below line of code to create a dictionary and this will be used for below exercises

# %%
raw_data = {"name": ['Bulbasaur', 'Charmander','Squirtle','Caterpie'],
            "evolution": ['Ivysaur','Charmeleon','Wartortle','Metapod'],
            "type": ['grass', 'fire', 'water', 'bug'],
            "hp": [45, 39, 44, 45],
            "pokedex": ['yes', 'no','yes','no']                        
            }

# %% [markdown]
# ### 3. Assign it to a object called pokemon and it should be a pandas DataFrame

# %%
pokemon = pd.DataFrame(raw_data)

# %%
pokemon.head()
# Out:
#          name   evolution   type  hp pokedex
# 0   Bulbasaur     Ivysaur  grass  45     yes
# 1  Charmander  Charmeleon   fire  39      no
# 2    Squirtle   Wartortle  water  44     yes
# 3    Caterpie     Metapod    bug  45      no

# %% [markdown]
# ### 4. If the DataFrame columns are in alphabetical order, change the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[['name', 'type', 'hp', 'evolution', 'pokedex']]

# %%
pokemon
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# ### 5. Add another column called place, and insert places (lakes, parks, hills, forest etc) of your choice.

# %%
pokemon['place'] = ['parks','forest','lakes','hills']

# %%
pokemon
# Out:
#          name   type  hp   evolution pokedex   place
# 0   Bulbasaur  grass  45     Ivysaur     yes   parks
# 1  Charmander   fire  39  Charmeleon      no  forest
# 2    Squirtle  water  44   Wartortle     yes   lakes
# 3    Caterpie    bug  45     Metapod      no   hills

# %% [markdown]
# ### 6. Display the data type of each column

# %%
pokemon.dtypes
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# pokedex      object
# place        object
# dtype: object

# %% [markdown]
# ### 7. Display the info of dataframe

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       4 non-null      object
#  1   type       4 non-null      object
#  2   hp         4 non-null      int64
#  3   evolution  4 non-null      object
#  4   pokedex    4 non-null      object
#  5   place      4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 320.0+ bytes

# %% [markdown]
# ## Section-2: The pupose of the below exercise (8-20) is to understand deleting data with pandas.
# ## The below exercises required to use wine.data

# %% [markdown]
# ### 8. Import the dataset *wine.txt* from the folder and assign it to a object called wine
#
# Please note that the original data text file doesn't contain any header. Please ensure that when you import the data, you should use a suitable argument so as to avoid data getting imported as header.

# %%
wine = pd.read_csv('Datasets/wine.txt',)

# %%
wine
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# 3    2.93   735
# 4    2.85  1450
# ..    ...   ...
# 172  1.74   740
# 173  1.56   750
# 174  1.56   835
# 175  1.62   840
# 176  1.60   560
#
# [177 rows x 14 columns]

# %% [markdown]
# ### 9. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine.drop(wine.columns[[0,3,6,8,10,12,13]],axis=1,inplace=True)

# %% [markdown]
# ### 10. Assign the columns as below:
#
# The attributes are (dontated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
column = ['alcohol','malic_acid','alcalinity_of_ash','magnesium','flavanoids','proanthocyanins','hue']
wine.columns = column

# %%
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0    13.20        1.78               11.2        100        2.76
# 1    13.16        2.36               18.6        101        3.24
# 2    14.37        1.95               16.8        113        3.49
# 3    13.24        2.59               21.0        118        2.69
# 4    14.20        1.76               15.2        112        3.39
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### 11. Set the values of the first 3 values from alcohol column as NaN

# %%
wine.alcohol[:3] = np.NAN

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN        1.78               11.2        100        2.76
# 1        NaN        2.36               18.6        101        3.24
# 2        NaN        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        0.61
# 173    13.40        3.91               23.0        102        0.75
# 174    13.27        4.28               20.0        120        0.69
# 175    13.17        2.59               20.0        120        0.68
# 176    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# 4               1.97  1.05
# ..               ...   ...
# 172             1.06  0.64
# 173             1.41  0.70
# 174             1.35  0.59
# 175             1.46  0.60
# 176             1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 12. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.magnesium[3:5] = np.nan

# %%
wine.head(10)
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN        1.78               11.2      100.0        2.76
# 1      NaN        2.36               18.6      101.0        3.24
# 2      NaN        1.95               16.8      113.0        3.49
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
# 5    14.39        1.87               14.6       96.0        2.52
# 6    14.06        2.15               17.6      121.0        2.51
# 7    14.83        1.64               14.0       97.0        2.98
# 8    13.86        1.35               16.0       98.0        3.15
# 9    14.10        2.16               18.0      105.0        3.32
#
#    proanthocyanins   hue
# 0             1.28  1.05
# 1             2.81  1.03
# 2             2.18  0.86
# 3             1.82  1.04
# 4             1.97  1.05
# 5             1.98  1.02
# 6             1.25  1.06
# 7             1.98  1.08
# 8             1.85  1.01
# 9             2.38  1.25

# %% [markdown]
# ### 13. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.alcohol.fillna(10,inplace=True)
wine.magnesium.fillna(100,inplace=True)

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 1      10.00        2.36               18.6      101.0        3.24
# 2      10.00        1.95               16.8      113.0        3.49
# 3      13.24        2.59               21.0      100.0        2.69
# 4      14.20        1.76               15.2      100.0        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# 4               1.97  1.05
# ..               ...   ...
# 172             1.06  0.64
# 173             1.41  0.70
# 174             1.35  0.59
# 175             1.46  0.60
# 176             1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 14. Count the number of missing values in all columns.

# %%
wine.isna().sum()
# Out:
# alcohol              0
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### 15.  Create an array of 10 random numbers up until 10 and save it.

# %%
arr = np.random.randint(0, 11, size=10)

# %%
arr
# Out:
# array([8, 5, 2, 2, 4, 6, 1, 7, 1, 7])

# %% [markdown]
# ### 16.  Set the rows corresponding to the random numbers to NaN in the column *alcohol*

# %%
wine.alcohol[arr] = np.nan

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 1        NaN        2.36               18.6      101.0        3.24
# 2        NaN        1.95               16.8      113.0        3.49
# 3      13.24        2.59               21.0      100.0        2.69
# 4        NaN        1.76               15.2      100.0        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# 4               1.97  1.05
# ..               ...   ...
# 172             1.06  0.64
# 173             1.41  0.70
# 174             1.35  0.59
# 175             1.46  0.60
# 176             1.35  0.61
#
# [177 rows x 7 columns]

# %% [markdown]
# ### 17.  How many missing values do we have now?

# %%
wine.isnull().sum()
# Out:
# alcohol              7
# malic_acid           0
# alcalinity_of_ash    0
# magnesium            0
# flavanoids           0
# proanthocyanins      0
# hue                  0
# dtype: int64

# %% [markdown]
# ### 18. Print only the non-null values in alcohol

# %%
print(wine['alcohol'][wine['alcohol'].notnull()])
# Out:
# 0      10.00
# 3      13.24
# 9      14.10
# 10     14.12
# 11     13.75
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: alcohol, Length: 170, dtype: float64

# %% [markdown]
# ### 19. Delete the rows that contain missing values

# %%
wine = wine.dropna()

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 3      13.24        2.59               21.0      100.0        2.69
# 9      14.10        2.16               18.0      105.0        3.32
# 10     14.12        1.48               16.8       95.0        2.43
# 11     13.75        1.73               16.0       89.0        2.76
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 3               1.82  1.04
# 9               2.38  1.25
# 10              1.57  1.17
# 11              1.81  1.15
# ..               ...   ...
# 172             1.06  0.64
# 173             1.41  0.70
# 174             1.35  0.59
# 175             1.46  0.60
# 176             1.35  0.61
#
# [170 rows x 7 columns]

# %% [markdown]
# ### 20.  Reset the index, so it starts with 0 again

# %%
wine.reset_index(drop=True,inplace=True)

# %%
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      10.00        1.78               11.2      100.0        2.76
# 1      13.24        2.59               21.0      100.0        2.69
# 2      14.10        2.16               18.0      105.0        3.32
# 3      14.12        1.48               16.8       95.0        2.43
# 4      13.75        1.73               16.0       89.0        2.76
# ..       ...         ...                ...        ...         ...
# 165    13.71        5.65               20.5       95.0        0.61
# 166    13.40        3.91               23.0      102.0        0.75
# 167    13.27        4.28               20.0      120.0        0.69
# 168    13.17        2.59               20.0      120.0        0.68
# 169    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               1.82  1.04
# 2               2.38  1.25
# 3               1.57  1.17
# 4               1.81  1.15
# ..               ...   ...
# 165             1.06  0.64
# 166             1.41  0.70
# 167             1.35  0.59
# 168             1.46  0.60
# 169             1.35  0.61
#
# [170 rows x 7 columns]

# %% [markdown]
# ## Section-3: The pupose of the below exercise (21-27) is to understand ***filtering & sorting*** data from dataframe.
# ## The below exercises required to use chipotle.tsv

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Import the dataset directly from this link (https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and create dataframe called chipo

# %%
chipo = pd.read_table('Datasets/chipotle.tsv')

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### 21. How many products cost more than $10.00?
#
# Use `str` attribute to remove the $ sign and convert the column to proper numeric type data before filtering.

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$','').astype(float)

# %%
len(chipo[chipo['item_price']>10.00])
# Out:
# 1130

# %% [markdown]
# ### 22. Print the Chipo Dataframe & info about data frame

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 180.7+ KB

# %% [markdown]
# ### 23. What is the price of each item?
# - Delete the duplicates in item_name and quantity
# - Print a data frame with only two columns `item_name` and `item_price`
# - Sort the values from the most to less expensive

# %%
data = chipo.drop_duplicates(subset=['item_name','quantity'])

# %%
data = data[['item_name','item_price']]

# %%
data
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 3890                  Carnitas Crispy Tacos       17.98
# 3973                      Canned Soft Drink        5.00
# 4152                          Bottled Water       15.00
# 4354                       Steak Soft Tacos       18.50
# 4489                    Chips and Guacamole       17.80
#
# [103 rows x 2 columns]

# %%
price = data.sort_values(by='item_price',ascending=False)
price
# Out:
#                          item_name  item_price
# 3598  Chips and Fresh Tomato Salsa       44.25
# 3480                 Carnitas Bowl       35.25
# 1254               Chicken Burrito       35.00
# 3601                Veggie Burrito       33.75
# 409                   Chicken Bowl       32.94
# ...                            ...         ...
# 40                           Chips        2.15
# 6                    Side of Chips        1.69
# 263              Canned Soft Drink        1.25
# 34                   Bottled Water        1.09
# 28                     Canned Soda        1.09
#
# [103 rows x 2 columns]

# %% [markdown]
# ### 24. Sort by the name of the item

# %%
name = data.sort_values(by='item_name',ascending=True)

# %%
name
# Out:
#                   item_name  item_price
# 298       6 Pack Soft Drink        6.49
# 3389      6 Pack Soft Drink       12.98
# 39            Barbacoa Bowl       11.75
# 21         Barbacoa Burrito        8.99
# 1903  Barbacoa Crispy Tacos       18.50
# ...                     ...         ...
# 1653    Veggie Crispy Tacos        8.49
# 1694           Veggie Salad        8.49
# 186       Veggie Salad Bowl       11.25
# 3889      Veggie Soft Tacos       16.98
# 738       Veggie Soft Tacos       11.25
#
# [103 rows x 2 columns]

# %% [markdown]
# ### 25. What was the quantity of the most expensive item ordered?

# %%
expensive_order = chipo.sort_values('item_price',ascending=False)
expensive_order = expensive_order.iloc[0].quantity
print('The quantity of the most expensive item ordered is',expensive_order)
# Out:
# The quantity of the most expensive item ordered is 15

# %% [markdown]
# ### 26. How many times were a Veggie Salad Bowl ordered?

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
vegord = len(chipo[chipo.item_name == 'Veggie Salad Bowl'])
print("No of times a Veggie Salad Bowl ordered is",vegord)
# Out:
# No of times a Veggie Salad Bowl ordered is 18

# %% [markdown]
# ### 27. How many times people orderd more than one Canned Soda?

# %%
canord = len(chipo[(chipo.item_name == 'Canned Soda')&(chipo.quantity > 1)])
print("No of times people orderd more than one Canned Soda is",canord)
# Out:
# No of times people orderd more than one Canned Soda is 20

# %% [markdown]
# ## Section-4: The purpose of the below exercises is to understand how to perform aggregations of data frame
# ## The below exercises (28-33) required to use occupation.csv

# %% [markdown]
# ###  28. Import the dataset occupation.csv and assign object as users

# %%
users = pd.read_csv('Datasets/occupation.csv',delimiter='|')

# %% [markdown]
# ### 29. Discover what is the mean age per occupation

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.groupby('occupation').agg({'age':'mean'})
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# ### 30. Discover the Male ratio per occupation and sort it from the most to the least.
#
# Use numpy.where() to encode gender column.

# %%
users['is_male'] = np.where(users.gender=='M',1,0)

# %%
users
# Out:
#      user_id  age gender     occupation zip_code  is_male
# 0          1   24      M     technician    85711        1
# 1          2   53      F          other    94043        0
# 2          3   23      M         writer    32067        1
# 3          4   24      M     technician    43537        1
# 4          5   33      F          other    15213        0
# ..       ...  ...    ...            ...      ...      ...
# 938      939   26      F        student    33319        0
# 939      940   32      M  administrator    02215        1
# 940      941   20      M        student    97229        1
# 941      942   48      F      librarian    78209        0
# 942      943   22      M        student    77841        1
#
# [943 rows x 6 columns]

# %%
ratio = users.groupby('occupation')['is_male'].sum()/users.groupby('occupation')['is_male'].count()
ratio = ratio.sort_values(ascending=False)

# %%
ratio
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: is_male, dtype: float64

# %%
users.groupby('occupation')['is_male'].count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: is_male, dtype: int64

# %%
users.groupby('occupation')['is_male'].sum()/users.groupby('occupation')['is_male'].count()
# Out:
# occupation
# administrator    0.544304
# artist           0.535714
# doctor           1.000000
# educator         0.726316
# engineer         0.970149
# entertainment    0.888889
# executive        0.906250
# healthcare       0.312500
# homemaker        0.142857
# lawyer           0.833333
# librarian        0.431373
# marketing        0.615385
# none             0.555556
# other            0.657143
# programmer       0.909091
# retired          0.928571
# salesman         0.750000
# scientist        0.903226
# student          0.693878
# technician       0.962963
# writer           0.577778
# Name: is_male, dtype: float64

# %% [markdown]
# ### 31. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation').agg({'age':[min,max]})
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %% [markdown]
# ### 32. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation','gender']).agg({'age':np.mean})
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# programmer    F       32.166667
#               M       33.216667
# retired       F       70.000000
#               M       62.538462
# salesman      F       27.000000
#               M       38.555556
# scientist     F       28.333333
#               M       36.321429
# student       F       20.750000
#               M       22.669118
# technician    F       38.000000
#               M       32.961538
# writer        F       37.631579
#               M       35.346154

# %% [markdown]
# ### 33.  For each occupation present the percentage of women and men

# %%
total_by_occ = users.groupby(['occupation']).agg({'gender':'count'})

# %%
gender_occ = users.groupby(['occupation','gender']).agg({'gender':'count'})

# %%
gender_pct = (gender_occ/total_by_occ)*100

# %%
gender_pct
# Out:
#                           gender
# occupation    gender
# administrator F        45.569620
#               M        54.430380
# artist        F        46.428571
#               M        53.571429
# doctor        M       100.000000
# educator      F        27.368421
#               M        72.631579
# engineer      F         2.985075
#               M        97.014925
# entertainment F        11.111111
#               M        88.888889
# executive     F         9.375000
#               M        90.625000
# healthcare    F        68.750000
#               M        31.250000
# homemaker     F        85.714286
#               M        14.285714
# lawyer        F        16.666667
#               M        83.333333
# librarian     F        56.862745
#               M        43.137255
# marketing     F        38.461538
#               M        61.538462
# none          F        44.444444
#               M        55.555556
# other         F        34.285714
#               M        65.714286
# programmer    F         9.090909
#               M        90.909091
# retired       F         7.142857
#               M        92.857143
# salesman      F        25.000000
#               M        75.000000
# scientist     F         9.677419
#               M        90.322581
# student       F        30.612245
#               M        69.387755
# technician    F         3.703704
#               M        96.296296
# writer        F        42.222222
#               M        57.777778

# %% [markdown]
# ## Section-6: The purpose of the below exercises is to understand how to use lambda-apply-functions
# ## The below exercises (34-41) required to use student-mat.csv and student-por.csv files

# %% [markdown]
# ### 34. Import the datasets *student-mat* and *student-por* and append them and assigned object as df

# %%
mat = pd.read_csv('Datasets/student-mat.csv')

# %%
por = pd.read_csv('Datasets/student-por.csv')

# %%
df = pd.concat([mat,por],axis=0)

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### 35. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
crop = df.loc[:,'school':'guardian']

# %%
crop
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian
# 0    course   mother
# 1    course   father
# 2     other   mother
# 3      home   mother
# 4      home   father
# ..      ...      ...
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother
#
# [1044 rows x 12 columns]

# %% [markdown]
# ### 36. Create a lambda function that captalize strings (example: if we give at_home as input function and should give At_home as output.

# %%
cap = lambda x: x.capitalize()

# %%
crop['Mjob'] = crop['Mjob'].apply(cap)

# %%
crop
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     other
# 2       GP   F   15       U     LE3       T     1     1   At_home     other
# 3       GP   F   15       U     GT3       T     4     2    Health  services
# 4       GP   F   16       U     GT3       T     3     3     Other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  Services     other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  services
# 646     MS   F   18       U     GT3       T     1     1     Other     other
# 647     MS   M   17       U     LE3       T     3     1  Services  services
# 648     MS   M   18       R     LE3       T     3     2  Services     other
#
#      reason guardian
# 0    course   mother
# 1    course   father
# 2     other   mother
# 3      home   mother
# 4      home   father
# ..      ...      ...
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother
#
# [1044 rows x 12 columns]

# %% [markdown]
# ### 37. Capitalize both Mjob and Fjob variables using above lamdba function

# %%
crop['Fjob'] = crop['Fjob'].apply(cap)

# %%
crop
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      reason guardian
# 0    course   mother
# 1    course   father
# 2     other   mother
# 3      home   mother
# 4      home   father
# ..      ...      ...
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother
#
# [1044 rows x 12 columns]

# %% [markdown]
# ### 38. Print the last elements of the data set. (Last few records)

# %%
crop.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      reason guardian
# 644  course   mother
# 645  course   mother
# 646  course   mother
# 647  course   mother
# 648  course   mother

# %% [markdown]
# ### 39. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df['Mjob'] = df['Mjob'].apply(cap)
df['Fjob'] = df['Fjob'].apply(cap)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [1044 rows x 33 columns]

# %% [markdown]
# ### 40. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(age):
    if age >= 21:
        return True
    else:
        return False

# %%
df['legal_drinker'] = df['age'].apply(majority)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  Services     Other
# 645     MS   F   18       U     LE3       T     3     1   Teacher  Services
# 646     MS   F   18       U     GT3       T     1     1     Other     Other
# 647     MS   M   17       U     LE3       T     3     1  Services  Services
# 648     MS   M   18       R     LE3       T     3     2  Services     Other
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 legal_drinker
# 0    ...        3     4     1     1       3        6   5   6   6         False
# 1    ...        3     3     1     1       3        4   5   5   6         False
# 2    ...        3     2     2     3       3       10   7   8  10         False
# 3    ...        2     2     1     1       5        2  15  14  15         False
# 4    ...        3     2     1     2       5        4   6  10  10         False
# ..   ...      ...   ...   ...   ...     ...      ...  ..  ..  ..           ...
# 644  ...        4     2     1     2       5        4  10  11  10         False
# 645  ...        3     4     1     1       1        4  15  15  16         False
# 646  ...        1     1     1     1       5        6  11  12   9         False
# 647  ...        4     5     3     4       2        6  10  10  10         False
# 648  ...        4     1     3     4       5        4  10  11  11         False
#
# [1044 rows x 34 columns]

# %% [markdown]
# ### 41. Multiply every number of the dataset by 10.

# %%
df.select_dtypes('int64') * 10
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    180    40    40          20         20         0      40        30
# 1    170    10    10          10         20         0      50        30
# 2    150    10    10          10         20        30      40        30
# 3    150    40    20          10         30         0      30        20
# 4    160    30    30          10         20         0      40        30
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 644  190    20    30          10         30        10      50        40
# 645  180    30    10          10         20         0      40        30
# 646  180    10    10          20         20         0      10        10
# 647  170    30    10          20         10         0      20        40
# 648  180    30    20          30         10         0      40        40
#
#      goout  Dalc  Walc  health  absences   G1   G2   G3
# 0       40    10    10      30        60   50   60   60
# 1       30    10    10      30        40   50   50   60
# 2       20    20    30      30       100   70   80  100
# 3       20    10    10      50        20  150  140  150
# 4       20    10    20      50        40   60  100  100
# ..     ...   ...   ...     ...       ...  ...  ...  ...
# 644     20    10    20      50        40  100  110  100
# 645     40    10    10      10        40  150  150  160
# 646     10    10    10      50        60  110  120   90
# 647     50    30    40      20        60  100  100  100
# 648     10    30    40      50        40  100  110  110
#
# [1044 rows x 16 columns]

# %% [markdown]
# ## Section-6: The purpose of the below exercises is to understand how to perform simple joins
# ## The below exercises (42-48) required to use cars1.csv and cars2.csv files

# %% [markdown]
# ### 42. Import the datasets cars1.csv and cars2.csv and assign names as cars1 and cars2

# %%
cars1 = pd.read_csv('Datasets/cars1.csv')
cars2 = pd.read_csv('Datasets/cars2.csv')

# %% [markdown]
#    ### 43. Print the information to cars1 by applying below functions
#    hint: Use different functions/methods like type(), head(), tail(), columns(), info(), dtypes(), index(), shape(), count(), size(), ndim(), axes(), describe(), memory_usage(), sort_values(), value_counts()
#    Also create profile report using pandas_profiling.Profile_Report

# %%
cars1.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement      int64
# horsepower       object
# weight            int64
# acceleration    float64
# model             int64
# origin            int64
# car              object
# Unnamed: 9      float64
# Unnamed: 10     float64
# Unnamed: 11     float64
# Unnamed: 12     float64
# Unnamed: 13     float64
# dtype: object

# %%
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0       1  chevrolet chevelle malibu         NaN          NaN          NaN
# 1       1          buick skylark 320         NaN          NaN          NaN
# 2       1         plymouth satellite         NaN          NaN          NaN
# 3       1              amc rebel sst         NaN          NaN          NaN
# 4       1                ford torino         NaN          NaN          NaN
#
#    Unnamed: 12  Unnamed: 13
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
cars1.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                 car  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 193       1       ford maverick         NaN          NaN          NaN
# 194       1          amc hornet         NaN          NaN          NaN
# 195       1  chevrolet chevette         NaN          NaN          NaN
# 196       1     chevrolet woody         NaN          NaN          NaN
# 197       2           vw rabbit         NaN          NaN          NaN
#
#      Unnamed: 12  Unnamed: 13
# 193          NaN          NaN
# 194          NaN          NaN
# 195          NaN          NaN
# 196          NaN          NaN
# 197          NaN          NaN

# %%
cars1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
cars1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           198 non-null    float64
#  1   cylinders     198 non-null    int64
#  2   displacement  198 non-null    int64
#  3   horsepower    198 non-null    object
#  4   weight        198 non-null    int64
#  5   acceleration  198 non-null    float64
#  6   model         198 non-null    int64
#  7   origin        198 non-null    int64
#  8   car           198 non-null    object
#  9   Unnamed: 9    0 non-null      float64
#  10  Unnamed: 10   0 non-null      float64
#  11  Unnamed: 11   0 non-null      float64
#  12  Unnamed: 12   0 non-null      float64
#  13  Unnamed: 13   0 non-null      float64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 21.8+ KB

# %%
cars1.shape
# Out:
# (198, 14)

# %%
cars1.size
# Out:
# 2772

# %%
cars1.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  198.000000  198.000000    198.000000   198.000000    198.000000
# mean    19.719697    5.898990    223.469697  3177.888889     15.005556
# std      5.814254    1.785417    115.181017   934.783733      2.872382
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     15.000000    4.000000    113.250000  2302.500000     13.000000
# 50%     19.000000    6.000000    228.000000  3030.000000     15.000000
# 75%     24.375000    8.000000    318.000000  4080.750000     16.800000
# max     35.000000    8.000000    455.000000  5140.000000     23.500000
#
#             model      origin  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# count  198.000000  198.000000         0.0          0.0          0.0
# mean    72.818182    1.439394         NaN          NaN          NaN
# std      1.865332    0.708085         NaN          NaN          NaN
# min     70.000000    1.000000         NaN          NaN          NaN
# 25%     71.000000    1.000000         NaN          NaN          NaN
# 50%     73.000000    1.000000         NaN          NaN          NaN
# 75%     74.000000    2.000000         NaN          NaN          NaN
# max     76.000000    3.000000         NaN          NaN          NaN
#
#        Unnamed: 12  Unnamed: 13
# count          0.0          0.0
# mean           NaN          NaN
# std            NaN          NaN
# min            NaN          NaN
# 25%            NaN          NaN
# 50%            NaN          NaN
# 75%            NaN          NaN
# max            NaN          NaN

# %%
cars1.memory_usage()
# Out:
# Index            128
# mpg             1584
# cylinders       1584
# displacement    1584
# horsepower      1584
# weight          1584
# acceleration    1584
# model           1584
# origin          1584
# car             1584
# Unnamed: 9      1584
# Unnamed: 10     1584
# Unnamed: 11     1584
# Unnamed: 12     1584
# Unnamed: 13     1584
# dtype: int64

# %%
cars1.value_counts()
# Out:
# Series([], dtype: int64)

# %%
profile = pp.ProfileReport(cars1)
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
profile.to_file('profile.html')
# Out:
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### 44. It seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.isnull().sum()
# Out:
# mpg               0
# cylinders         0
# displacement      0
# horsepower        0
# weight            0
# acceleration      0
# model             0
# origin            0
# car               0
# Unnamed: 9      198
# Unnamed: 10     198
# Unnamed: 11     198
# Unnamed: 12     198
# Unnamed: 13     198
# dtype: int64

# %%
cars1.dropna(axis=1, inplace=True)

# %% [markdown]
# ### 45. What is the number of observations in each dataset?

# %%
print('Observations in cars1 dataset is',cars1.shape[0])
print('Observations in cars2 dataset is',cars2.shape[0])
# Out:
# Observations in cars1 dataset is 198
# Observations in cars2 dataset is 200

# %% [markdown]
# ### 46. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = pd.concat([cars1,cars2],axis=0)

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 195       1            ford mustang gl
# 196       2                  vw pickup
# 197       1              dodge rampage
# 198       1                ford ranger
# 199       1                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 47. There is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
owners = np.random.randint(15000,73001, cars.shape[0])

# %%
owners
# Out:
# array([60672, 72035, 45612, 36343, 16960, 36948, 43656, 56232, 62792,
#        67478, 60651, 24878, 32363, 33551, 45101, 44262, 51188, 15100,
#        53787, 23867, 19519, 55134, 72075, 66794, 27579, 25117, 25199,
#        58416, 62211, 40708, 69978, 18292, 25275, 25978, 65393, 37801,
#        21725, 32218, 62793, 29063, 59065, 71192, 57657, 40121, 23534,
#        21449, 30821, 68044, 25311, 56224, 18514, 66094, 24513, 15735,
#        56191, 52623, 42771, 49406, 22766, 33673, 32118, 22178, 40809,
#        62487, 51498, 40596, 63799, 27317, 56387, 29655, 46285, 47193,
#        60361, 34339, 23564, 55048, 28355, 61510, 61639, 60142, 35640,
#        67689, 48436, 43726, 27582, 31587, 32394, 19056, 47413, 48913,
#        22884, 23052, 33189, 20095, 47095, 55363, 63536, 31441, 15138,
#        25955, 59803, 42553, 34116, 52404, 54179, 60331, 47872, 23881,
#        30126, 64269, 50684, 27923, 53689, 45474, 48286, 23532, 57132,
#        43735, 24627, 64851, 34931, 34128, 29766, 22246, 19130, 50530,
#        38515, 45613, 61577, 36122, 19915, 26841, 41910, 49145, 58411,
#        30612, 34497, 22021, 55074, 38915, 61423, 47744, 24984, 67590,
#        65285, 63651, 55202, 42718, 15527, 35036, 34910, 66094, 54979,
#        56401, 45202, 51524, 63767, 32459, 55070, 38320, 33218, 65191,
#        69061, 41977, 63305, 37925, 72646, 26199, 51583, 19268, 64763,
#        40722, 43743, 28928, 19982, 36335, 70511, 33814, 64043, 63436,
#        58647, 54288, 37439, 24924, 69614, 19446, 41688, 63497, 15521,
#        36418, 50853, 45470, 46358, 70818, 44891, 18550, 57708, 50632,
#        70657, 44283, 32489, 71648, 31031, 20619, 69421, 72329, 68001,
#        67429, 26741, 67318, 66352, 70872, 27913, 37166, 35825, 18118,
#        34489, 72837, 45878, 19438, 71904, 18964, 29767, 45943, 50005,
#        24712, 53825, 57160, 58425, 15517, 59012, 63913, 19771, 33693,
#        29257, 66053, 64322, 66251, 17711, 31675, 25579, 44034, 46052,
#        62876, 33945, 19213, 65415, 20105, 36304, 67060, 46068, 55979,
#        24249, 23427, 21031, 25837, 18931, 21720, 60884, 26876, 53693,
#        49204, 36583, 25806, 42564, 22589, 28696, 26788, 39386, 70885,
#        36824, 30275, 34383, 66615, 27253, 35784, 24307, 61360, 60670,
#        17673, 65245, 18737, 20640, 44960, 54306, 68314, 52148, 55932,
#        24262, 31462, 55849, 67143, 33365, 72040, 26780, 34021, 38250,
#        50340, 37441, 45096, 69984, 19958, 44353, 36133, 21546, 57389,
#        32427, 45873, 49147, 15543, 64169, 47936, 35295, 57198, 30264,
#        53320, 58382, 71669, 53660, 39827, 44739, 47289, 20096, 24805,
#        71102, 55957, 44497, 32957, 70629, 23972, 25600, 51467, 59616,
#        22748, 71945, 61488, 68843, 48561, 54436, 70571, 29757, 58710,
#        66670, 66938, 44432, 55414, 29371, 50541, 22456, 49854, 63445,
#        65824, 31137, 66420, 43605, 30767, 45654, 57173, 26119, 21391,
#        29377, 61287, 38958, 22369, 51308, 34816, 40103, 72059, 16043,
#        39578, 18716, 54753, 70817, 63966, 22921, 43709, 39410, 69438,
#        64115, 41196, 20234, 28121, 68885, 42990, 39443, 71634, 43713,
#        72110, 30642, 21500, 31672, 51831, 49261, 31353, 15401, 17182,
#        18590, 56152])

# %% [markdown]
# ### 48. Add the column owners to cars

# %%
cars['owners'] = owners

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# 0         1  chevrolet chevelle malibu   60672
# 1         1          buick skylark 320   72035
# 2         1         plymouth satellite   45612
# 3         1              amc rebel sst   36343
# 4         1                ford torino   16960
# ..      ...                        ...     ...
# 195       1            ford mustang gl   31353
# 196       2                  vw pickup   15401
# 197       1              dodge rampage   17182
# 198       1                ford ranger   18590
# 199       1                 chevy s-10   56152
#
# [398 rows x 10 columns]

# %% [markdown]
# ## Section-7: The purpose of the below exercises is to understand how to perform date time operations

# %% [markdown]
# ### 49. Write a Python script to display the
# - a. Current date and time
# - b. Current year
# - c. Month of year
# - d. Week number of the year
# - e. Weekday of the week
# - f. Day of year
# - g. Day of the month
# - h. Day of week

# %%
now = dt.datetime.now()
print("Current date and time:", now)
print("Current year:", now.year)
print("Month of year:", now.month)
print("Week number of the year:", now.isocalendar()[1])
print("Weekday of the week (Monday is 1 and Sunday is 7):", now.isoweekday())
print("Day of year:", now.timetuple().tm_yday)
print("Day of the month:", now.day)
print("Day of week (Monday is 0 and Sunday is 6):", now.weekday())
# Out:
# Current date and time: 2023-03-13 15:35:25.205672
# Current year: 2023
# Month of year: 3
# Week number of the year: 11
# Weekday of the week (Monday is 1 and Sunday is 7): 1
# Day of year: 72
# Day of the month: 13
# Day of week (Monday is 0 and Sunday is 6): 0

# %% [markdown]
# ### 50. Write a Python program to convert a string to datetime.
# Sample String : Jul 1 2014 2:43PM
#
# Expected Output : 2014-07-01 14:43:00

# %%
print(dt.datetime.strptime('Jul 1 2014 2:43PM', '%b %d %Y %I:%M%p'))
# Out:
# 2014-07-01 14:43:00

# %% [markdown]
# ### 51. Write a Python program to subtract five days from current date.
#
# Current Date : 2015-06-22
#
# 5 days before Current Date : 2015-06-17

# %%
date = '2015-06-22'
current_date = dt.datetime.strptime(date, '%Y-%m-%d')

# %%
new_date = current_date - dt.timedelta(days=5)

# %%
print(new_date)
# Out:
# 2015-06-17 00:00:00

# %% [markdown]
# ### 52. Write a Python program to convert unix timestamp string to readable date.
#
# Sample Unix timestamp string : 1284105682
#
# Expected Output : 2010-09-10 13:31:22

# %%
sample = 1284105682
dt.datetime.fromtimestamp(sample).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2010-09-10 13:31:22'

# %% [markdown]
# ### 53. Convert the below Series to pandas datetime :
#
# DoB = pd.Series(["07Sep59","01Jan55","15Dec47","11Jul42"])
#
# Make sure that the year is 19XX not 20XX

# %%
DoB = pd.Series(["07Sep59","01Jan55","15Dec47","11Jul42"])
dob = pd.to_datetime(DoB) - dt.timedelta(days=365.25*100)

# %%
dob
# Out:
# 0   1959-09-07
# 1   1955-01-01
# 2   1947-12-15
# 3   1942-07-11
# dtype: datetime64[ns]

# %% [markdown]
# ### 54. Write a Python program to get days between two dates.

# %%
def datedifference(p, n):
    x = pd.to_datetime(p, format = '%Y-%m-%d')
    y = pd.to_datetime(n, format = '%Y-%m-%d')
    return (x-y).days

# %%
datedifference('2023-11-20','2020-10-5')
# Out:
# 1141

# %% [markdown]
# ### 55. Convert the below date to datetime and then change its display format using the .dt module
#
# Date = "15Dec1989"
#
# Result : "Friday, 15 Dec 98"

# %%
Date = dt.datetime.strptime('15Dec1989', '%d%b%Y').strftime('%A, %d %b %y')
Date
# Out:
# 'Friday, 15 Dec 89'

# %% [markdown]
# ## The below exercises (56-66) required to use wind.data file

# %% [markdown]
# ### About wind.data:
#
# The data have been modified to contain some missing values, identified by NaN.
#
# 1. The data in 'wind.data' has the following format:

# %% [raw]
# """
# Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
# 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
# 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
# """
# The first three columns are year, month and day.  The remaining 12 columns are average windspeeds in knots at 12 locations in Ireland on that day.

# %% [markdown]
# ### 56. Import the dataset wind.data and assign it to a variable called data and replace the first 3 columns by a proper date time index

# %%
data = pd.read_table('Datasets/wind.data',delimiter=',')

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# 2      8.50   7.67  12.75  12.71
# 3      5.83   5.88   5.46  10.88
# 4     10.92  10.34  12.92  11.83
# ...     ...    ...    ...    ...
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08
#
# [6574 rows x 15 columns]

# %%
data['Date'] = data['Yr'].astype(str) + '-' + data['Mo'].astype(str) + '-' + data['Dy'].astype(str)

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data = data.drop(['Yr','Mo','Dy'],axis=1)

# %%
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL       Date
# 0     18.50  15.04 2061-01-01
# 1     17.54  13.83 2061-01-02
# 2     12.75  12.71 2061-01-03
# 3      5.46  10.88 2061-01-04
# 4     12.92  11.83 2061-01-05
# ...     ...    ...        ...
# 6569  17.21  40.08 1978-12-27
# 6570  21.79  41.46 1978-12-28
# 6571  18.88  29.58 1978-12-29
# 6572  14.67  28.79 1978-12-30
# 6573  12.08  22.08 1978-12-31
#
# [6574 rows x 13 columns]

# %% [markdown]
# ### 57. Year 2061 is seemingly imporoper. Convert every year which are < 70 to 19XX instead of 20XX.

# %%
data['Date'] = np.where(data['Date'].dt.year > 2000,
                        data['Date'] - dt.timedelta(days= 365.25*100), 
                        data['Date'])

# %%
data.head()
# Out:
#      RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL    CLO    BEL  \
# 0  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83  12.58  18.50
# 1  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79   9.67  17.54
# 2  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50   7.67  12.75
# 3  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83   5.88   5.46
# 4  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92  10.34  12.92
#
#      MAL       Date
# 0  15.04 1961-01-01
# 1  13.83 1961-01-02
# 2  12.71 1961-01-03
# 3  10.88 1961-01-04
# 4  11.83 1961-01-05

# %% [markdown]
# ### 58. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data = data.set_index('Date')

# %%
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# ### 59. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### 60. Compute how many non-missing values there are in total.

# %%
len(data) - data.isnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### 61. Calculate the mean windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data = data.fillna(data.mean())

# %%
mean_windspeed = data.mean().mean()
mean_windspeed
# Out:
# 10.227982360836924

# %%
print(f"Mean windspeed over all locations and times is {mean_windspeed}")
# Out:
# Mean windspeed over all locations and times is 10.227982360836924

# %% [markdown]
# ### 62. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats = data.describe().transpose()

# %%
loc_stats = loc_stats.loc[:,['min','max','mean','std']]

# %%
loc_stats
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.615848
# VAL  0.21  33.37  10.644314  5.266154
# ROS  1.50  33.84  11.660526  5.007688
# KIL  0.00  28.46   6.306468  3.604439
# SHA  0.13  37.54  10.455834  4.935374
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.976419
# CLA  0.00  31.08   8.495053  4.498764
# MUL  0.00  25.88   8.493590  4.165921
# CLO  0.04  28.21   8.707332  4.503612
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.697755

# %% [markdown]
# ### 63. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
df = data.transpose()

# %%
day_stats = df.describe().transpose()

# %%
day_stats = day_stats.loc[:,['min','max','mean','std']]

# %%
day_stats
# Out:
#              min    max       mean       std
# Date
# 1961-01-01  9.29  18.50  12.804653  2.778428
# 1961-01-02  6.50  17.54  11.278693  3.047143
# 1961-01-03  6.17  18.50  11.379588  3.626189
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# ### 64. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
df = data[data.index.month == 1]

# %%
df.head()
# Out:
#               RPT        VAL    ROS    KIL        SHA   BIR    DUB        CLA  \
# Date
# 1961-01-01  15.04  14.960000  13.17   9.29  10.455834  9.87  13.67  10.250000
# 1961-01-02  14.71  10.644314  10.83   6.50  12.620000  7.67  11.50  10.040000
# 1961-01-03  18.50  16.880000  12.33  10.13  11.170000  6.17  11.25   8.495053
# 1961-01-04  10.58   6.630000  11.75   4.58   4.540000  2.88   8.63   1.790000
# 1961-01-05  13.33  13.250000  11.42   6.17  10.710000  8.21  11.92   6.540000
#
#               MUL    CLO    BEL    MAL
# Date
# 1961-01-01  10.83  12.58  18.50  15.04
# 1961-01-02   9.79   9.67  17.54  13.83
# 1961-01-03   8.50   7.67  12.75  12.71
# 1961-01-04   5.83   5.88   5.46  10.88
# 1961-01-05  10.92  10.34  12.92  11.83

# %%
df = df.mean()

# %%
df
# Out:
# RPT    14.842873
# VAL    12.910492
# ROS    13.299624
# KIL     7.199498
# SHA    11.663390
# BIR     8.054839
# DUB    11.819355
# CLA     9.510224
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### 65. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
monthly_windspeed = data.groupby( lambda x: (x.month, x.year)).mean()

# %%
monthly_windspeed
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# (1, 1961)   14.761387  11.944978  13.431613  7.736774  11.032957   8.588065
# (1, 1962)   14.783871  13.160323  12.591935  7.538065  11.779677   8.720000
# (1, 1963)   14.868387  11.112903  15.121613  6.635806  11.080645   7.835484
# (1, 1964)   12.661290  11.818387  11.741290  6.953548  11.400645   6.865806
# (1, 1965)   15.741613  15.546774  15.274194  8.258387  13.588065   9.251290
# ...               ...        ...        ...       ...        ...        ...
# (12, 1974)  18.511290  17.805806  14.773871  9.734839  16.944194  10.153871
# (12, 1975)  11.655484   8.686774  11.217742  4.478387   6.628710   4.178065
# (12, 1976)  11.962258  10.086774  10.474516  3.383871   7.645484   6.148387
# (12, 1977)  14.751935  12.744839  13.469677  6.592258  11.247742   9.466774
# (12, 1978)  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
#                   DUB        CLA        MUL        CLO        BEL        MAL
# (1, 1961)   11.184839   9.221131   9.085806  10.107419  13.880968  14.703226
# (1, 1962)   14.211935   9.600000   9.670000  11.498710  16.369355  15.661613
# (1, 1963)   12.797419   9.844839   7.841613   9.390000  11.428710  18.822258
# (1, 1964)    9.592903   9.687419   6.947742   9.676774  15.067419  14.145484
# (1, 1965)   13.850968  11.260000   9.899355  11.706129  16.196129  17.888710
# ...               ...        ...        ...        ...        ...        ...
# (12, 1974)  16.602903  15.034194  14.883548  12.915161  18.803548  24.124194
# (12, 1975)  10.351290   6.176129   8.401935   7.342903  12.028710  18.689032
# (12, 1976)   8.034516   4.500000   5.952258   6.147742   7.814839  14.346774
# (12, 1977)  13.231613  10.703871  10.401613   9.415484  13.237419  19.299677
# (12, 1978)  12.077419  10.194839  10.616774  11.028710  13.859677  21.371613
#
# [216 rows x 12 columns]

# %% [markdown]
# ### 66. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
week = data.resample('W',loffset='1D').agg(['min','max','mean','std'])

# %%
week.head()
# Out:
#                   RPT                                VAL                    \
#                   min    max       mean       std    min    max       mean
# Date
# 1961-01-02  15.040000  15.04  15.040000       NaN  14.96  14.96  14.960000
# 1961-01-09  10.580000  18.50  13.541429  2.631321   6.63  16.88  11.366331
# 1961-01-16   9.040000  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-23   4.920000  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-30  12.362987  25.04  18.806141  5.084484   9.96  23.91  16.141429
#
#                         ROS         ...        CLO              BEL         \
#                  std    min    max  ...       mean       std    min    max
# Date                                ...
# 1961-01-02       NaN  13.17  13.17  ...  12.580000       NaN  18.50  18.50
# 1961-01-09  3.619437   7.62  12.33  ...   8.497143  1.704941   5.46  17.54
# 1961-01-16  3.148945   7.08  19.50  ...   7.571429  4.084293   5.25  20.71
# 1961-01-23  3.837785   7.29  20.79  ...   8.124286  4.783952   6.50  15.92
# 1961-01-30  5.170224  12.67  25.84  ...  15.640000  3.713368  14.04  27.71
#
#                                    MAL
#                  mean       std    min    max       mean       std
# Date
# 1961-01-02  18.500000       NaN  15.04  15.04  15.040000       NaN
# 1961-01-09  12.481429  4.349139  10.88  16.46  13.238571  1.773062
# 1961-01-16  11.125714  5.552215   5.17  16.92  11.024286  4.692355
# 1961-01-23   9.821429  3.626584   6.79  17.96  11.434286  4.237239
# 1961-01-30  20.930000  5.210726  17.50  27.63  22.530000  3.874721
#
# [5 rows x 48 columns]

# %% [markdown]
# ## The below exercises (67-70) required to use appl_1980_2014.csv  file

# %% [markdown]
# ### 67. Import the file appl_1980_2014.csv and assign it to a variable called 'apple'

# %%
apple = pd.read_csv('Datasets/appl_1980_2014.csv')

# %%
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### 68.  Check out the type of the columns

# %%
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   object
#  1   Open       8465 non-null   float64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.1+ KB

# %% [markdown]
# ### 69. Transform the Date column as a datetime type

# %%
apple.Date = pd.to_datetime(apple.Date)

# %% [markdown]
# ### 70.  Set the date as the index

# %%
apple = apple.set_index('Date')

# %% [markdown]
# ### 71.  Is there any duplicate dates?

# %%
apple.index.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 72.  The index is from the most recent date. Sort the data so that the first entry is the oldest date.

# %%
apple = apple.sort_index(ascending = True)

# %%
apple
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...           ...    ...    ...    ...        ...        ...
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 6 columns]

# %% [markdown]
# ### 73. Get the last business day of each month

# %%
last_business_day = apple[apple.index.is_month_end]

# %%
last_business_day
# Out:
#               Open    High     Low   Close     Volume  Adj Close
# Date
# 1980-12-31   34.25   34.25   34.13   34.13    8937600       0.53
# 1981-03-31   24.75   24.75   24.50   24.50    3998400       0.38
# 1981-04-30   28.38   28.62   28.38   28.38    3152800       0.44
# 1981-06-30   26.13   26.13   26.00   26.00    8976800       0.41
# 1981-07-31   25.00   25.12   25.00   25.00    2738400       0.39
# ...            ...     ...     ...     ...        ...        ...
# 2014-01-31  495.18  501.53  493.55  500.60  116199300      70.69
# 2014-02-28  529.08  532.75  522.12  526.24   92992200      74.76
# 2014-03-31  539.23  540.81  535.93  536.74   42167300      76.25
# 2014-04-30  592.64  599.43  589.80  590.09  114160200      83.83
# 2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
#
# [283 rows x 6 columns]

# %% [markdown]
# ### 74.  What is the difference in days between the first day and the oldest

# %%
day_diff = apple.index[-1] - apple.index[1]

# %%
print(f'The difference in days between the first day and the oldest is {day_diff.days} days')
# Out:
# The difference in days between the first day and the oldest is 12258 days

# %% [markdown]
# ### 75.  How many months in the data we have?

# %%
num_months = len(apple.resample('M').sum().index)

# %%
print(f'The number of months we have is {num_months}')
# Out:
# The number of months we have is 404

# %% [markdown]
# ## Section-8: The purpose of the below exercises is to understand how to create basic graphs

# %% [markdown]
# ### 76. Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
plt.figure(figsize=(13.5,9))
plt.plot(apple['Adj Close'])
plt.show()

# %% [markdown]
# ## The below exercises (77-80) required to use Online_Retail.csv file

# %% [markdown]
# ### 77. Import the dataset from this Online_Retail.csv and assign it to a variable called online_rt

# %%
online_rt = pd.read_csv('Datasets/Online_Retail.csv', encoding='latin1')

# %%
online_rt
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/10 8:26       2.55     17850.0  United Kingdom
# 1        12/1/10 8:26       3.39     17850.0  United Kingdom
# 2        12/1/10 8:26       2.75     17850.0  United Kingdom
# 3        12/1/10 8:26       3.39     17850.0  United Kingdom
# 4        12/1/10 8:26       3.39     17850.0  United Kingdom
# ...               ...        ...         ...             ...
# 541904  12/9/11 12:50       0.85     12680.0          France
# 541905  12/9/11 12:50       2.10     12680.0          France
# 541906  12/9/11 12:50       4.15     12680.0          France
# 541907  12/9/11 12:50       4.15     12680.0          France
# 541908  12/9/11 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### 78. Create a barchart with the 10 countries that have the most 'Quantity' ordered except UK

# %%
country_quantity = online_rt.groupby('Country')['Quantity'].sum()
top_countries = country_quantity.drop('United Kingdom').nlargest(10)
top_countries.plot(kind='bar', 
                   xlabel = 'Country',
                   title = 'Top 10 Countries by Quantity Ordered (Excluding UK)')
# Out:
# <AxesSubplot: title={'center': 'Top 10 Countries by Quantity Ordered (Excluding UK)'}, xlabel='Country'>

# %% [markdown]
# ### 79.  Exclude negative Quatity entries

# %%
online_rt = online_rt[online_rt.Quantity>0].reset_index(drop=True)

# %%
online_rt
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 531280    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 531281    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 531282    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 531283    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 531284    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/10 8:26       2.55     17850.0  United Kingdom
# 1        12/1/10 8:26       3.39     17850.0  United Kingdom
# 2        12/1/10 8:26       2.75     17850.0  United Kingdom
# 3        12/1/10 8:26       3.39     17850.0  United Kingdom
# 4        12/1/10 8:26       3.39     17850.0  United Kingdom
# ...               ...        ...         ...             ...
# 531280  12/9/11 12:50       0.85     12680.0          France
# 531281  12/9/11 12:50       2.10     12680.0          France
# 531282  12/9/11 12:50       4.15     12680.0          France
# 531283  12/9/11 12:50       4.15     12680.0          France
# 531284  12/9/11 12:50       4.95     12680.0          France
#
# [531285 rows x 8 columns]

# %% [markdown]
# ### 80. Create a scatterplot with the Quantity per UnitPrice by CustomerID for the top 3 Countries
# Hint: First we need to find top-3 countries based on revenue, then create scater plot between Quantity and Unitprice for each country separately

# %%
online_rt['revenue'] = online_rt.Quantity * online_rt.UnitPrice

# %%
top_country = online_rt.groupby('Country')['revenue'].sum()

# %%
top_country = top_country.sort_values(ascending=False)[:3].index

# %%
for country in top_country:
    data = online_rt[online_rt['Country'] == country]
    plt.scatter(data["UnitPrice"], data["Quantity"])
    plt.title(f'Scatter plot for {country}')
    plt.ylabel('Quantity')
    plt.xlabel('Unit Price')
    plt.show()

# %% [markdown]
# ## The below exercises (81-90) required to use FMCG_Company_Data_2019.csv file

# %% [markdown]
# ### 81. Import the dataset FMCG_Company_Data_2019.csv and assign it to a variable called company_data

# %%
company_data = pd.read_csv('Datasets/FMCG_Company_Data_2019.csv')

# %%
company_data
# Out:
#      Month  FaceCream  FaceWash  ToothPaste   Soap  Shampo  Moisturizer  \
# 0   Jan-19       2500      1500        5200   9200    1200         1500
# 1   Feb-19       2630      1200        5100   6100    2100         1200
# 2   Mar-19       2140      1340        4550   9550    3550         1340
# 3   Apr-19       3400      1130        5870   8870    1870         1130
# 4   May-19       3600      1740        4560   7760    1560         1740
# 5   Jun-19       2760      1555        4890   7490    1890         1555
# 6   Jul-19       2980      1120        4780   8980    1780         1120
# 7   Aug-19       3700      1400        5860   9960    2860         1400
# 8   Sep-19       3540      1780        6100   8100    2100         1780
# 9   Oct-19       1990      1890        8300  10300    2300         1890
# 10  Nov-19       2340      2100        7300  13300    2400         2100
# 11  Dec-19       2900      1760        7400  14400    1800         1760
#
#     Total_Units  Total_Revenue  Total_Profit
# 0         21100        3584890        211000
# 1         18330        2864979        183300
# 2         22470        4058082        224700
# 3         22270        2890646        222700
# 4         20960        2997280        209600
# 5         20140        2857866        201400
# 6         29550        5735655        295500
# 7         36140        5196932        361400
# 8         23400        3060720        234000
# 9         26670        4661916        266700
# 10        41280        6794688        412800
# 11        30020        3770512        300200

# %% [markdown]
# ### 82. Create line chart for Total Revenue of all months with following properties
# - X label name = Month
# - Y label name = Total Revenue

# %%
plt.figure(figsize=(12,6))
plt.plot(company_data.Month,company_data.Total_Revenue)
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.show()

# %% [markdown]
# ### 83. Create line chart for Total Units of all months with following properties
# - X label name = Month
# - Y label name = Total Units
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location.

# %%
plt.figure(figsize=(12,6))
plt.plot(company_data.Month,company_data.Total_Units,marker='.', linestyle='--',color='g')
plt.xlabel('Month')
plt.ylabel('Total Revenue')
plt.legend(company_data.Total_Units,loc='lower right')
plt.show()

# %% [markdown]
# ### 84. Read all product sales data (Facecream, FaceWash, Toothpaste, Soap, Shampo, Moisturizer) and show it  using a multiline plot
# - Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).

# %%
plt.figure(figsize=(12,6))
plt.plot(company_data.Month, company_data.FaceCream, label = 'FaceCream')
plt.plot(company_data.Month, company_data.FaceWash, label = 'FaceWash') 
plt.plot(company_data.Month, company_data.ToothPaste, label = 'ToothPaste')
plt.plot(company_data.Month, company_data.Soap, label = 'Soap')
plt.plot(company_data.Month, company_data.Shampo, label = 'Shampo')
plt.plot(company_data.Month, company_data.Moisturizer, label = 'Moisturizer')
plt.legend(loc=0)
plt.title("Sales by Month")
plt.xlabel("Month")
plt.ylabel("Number of Units Sold")
plt.show()

# %% [markdown]
# ### 85. Create Bar Chart for soap of all months and Save the chart in folder

# %%
plt.figure(figsize=(12,6))
plt.bar(company_data.Month , company_data.Soap)
plt.title("Soap Sales by Month")
plt.xlabel("Month")
plt.ylabel("Number of Units Sold")
plt.savefig("soap_sales.png")
plt.show()

# %% [markdown]
# ### 86. Create Stacked Bar Chart for Soap, Shampo, ToothPaste for each month
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
df = company_data[['Month','Soap','Shampo','ToothPaste']]

# %%
df.plot(kind='bar',stacked = False, figsize=(12,6))
plt.title("Sales by Month")
plt.xlabel("Month")
plt.ylabel("Number of Units Sold")
plt.show()

# %% [markdown]
# ### 87. Create Histogram for Total Revenue

# %%
plt.hist(company_data.Total_Revenue)
plt.title("Total Revenue Histogram")
plt.xlabel("Total Revenue")
plt.show()

# %% [markdown]
# ### 88. Calculate total sales data (quantity) for 2019 for each product and show it using a Pie chart. Understand percentage contribution from each product

# %%
i = company_data[['FaceCream','FaceWash','ToothPaste','Soap','Shampo','Moisturizer']]
totalsales = i.sum()
plt.pie(totalsales, labels=totalsales.index, autopct='%1.1f%%')
plt.title('Total Sales for 2019')
plt.show()

# %% [markdown]
# ### 89. Create line plots for Soap & Facewash of all months in a single plot using Subplot

# %%
fig , (ax1, ax2)= plt.subplots( 2, 1, figsize = (18, 10) )
ax1.plot(company_data.Month, company_data.Soap, label = 'Soap', c ='r')
ax1.set_title('Soap Sales')
ax1.set_ylabel('Number of Units Sold')
plt.legend
ax2.plot(company_data.Month, company_data.FaceWash, label = 'Facewash', c= 'g',)
ax2.set_title('Facewash Sales')
ax2.set_ylabel('Number of Units Sold')
plt.legend
plt.show()

# %% [markdown]
# ### 90. Create Box Plot for Total Profit variable

# %%
plt.boxplot(company_data.Total_Profit)
plt.title("Box Plot of Total Profit")
plt.show()
